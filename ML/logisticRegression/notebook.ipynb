# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression

# %%
data = pd.read_csv('data/sample.csv')
data.head()
# Out:
#    age  job
# 0   16    0
# 1   24    0
# 2   31    1
# 3   29    0
# 4   40    1

# %%
plt.scatter(data.age, data.job)

# %%
x = data[['age']]
x
# Out:
#     age
# 0    16
# 1    24
# 2    31
# 3    29
# 4    40
# 5    33
# 6    18
# 7    36
# 8    15
# 9    37
# 10   19
# 11   21
# 12   29
# 13   31
# 14   23
# 15   20
# 16   34
# 17   22
# 18   32
# 19   15
# 20   14
# 21   13
# 22   51
# 23   43
# 24   23
# 25   31

# %%
y = data[['job']]
y
# Out:
#     job
# 0     0
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     0
# 7     1
# 8     0
# 9     1
# 10    0
# 11    0
# 12    1
# 13    1
# 14    1
# 15    0
# 16    1
# 17    0
# 18    1
# 19    0
# 20    0
# 21    0
# 22    1
# 23    1
# 24    0
# 25    1

# %%
x_train, x_test , y_train, y_test = train_test_split(x, y, test_size=0.1)

# %%
x_test
# Out:
#     age
# 7    36
# 10   19
# 15   20

# %%
y_test
# Out:
#     job
# 7     1
# 10    0
# 15    0

# %%
model = LogisticRegression()

# %%
model.fit(x_train, y_train)
# Out:
# e:\learning\MachineLearning\codeprolk\machinelearning\.venv\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([1, 0, 0])

# %%
model.score(x_test, y_test)
# Out:
# 1.0

# %%
age = np.array([[20],[25],[30],[35]])
model.predict(age)
# Out:
# e:\learning\MachineLearning\codeprolk\machinelearning\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0, 0, 1, 1])

# %%
y_test
# Out:
#     job
# 7     1
# 10    0
# 15    0

# %%
age = np.array([[2]])
model.predict(age)
# Out:
# e:\learning\MachineLearning\codeprolk\machinelearning\.venv\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0])
